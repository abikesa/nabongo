# %% [markdown]
# #
#
# # 58
#
# *`May the fourth be with you!`*
#
# <Details>
# <Summary>1. Philosophy</Summary>
#
# (Data generating process)
#
# Agents - $F=ma$
# - gods
# - demigods
# - heroes
# - villains
# - mortals
#
# Verbs - $W=Fd$
# - create
# - shepherd
# - free
# - control
# - usurp
#
# Objects - $Credo$
# - cosmos
# - planets 🪐
# - life
# - emotion
# - social
#
# </Details>
#
# <Details>
# <Summary>2. Knowledge</Summary>
#
# $
# \Large
# \left\{
# \begin{array}{ll}
# \text{Truth/Free/Agent} \\
# \text{} \\
# \text{Know/John 8:32/Verb} \ \
# \left\{ \begin{array}{l} \text{Rigor} \text{} \\ \text{Error} \ \ \ \ \ \ \ \ \
# \left\{ \begin{array}{l} \text{Variance} \\ \text{Bias}  \end{array} \right. \\ \text{Sloppy}  \end{array} \right.
# \left\{ \begin{array}{l} \text{Information/Control} \end{array}  \right. \\
# \text{} \\
# \text{Morality/Slave/Object}
# \end{array}
# \right.
# $
#
# <Details>
#   <Summary></Summary>
#
#
# (Data generating process)
# *Agents - Rate
# - gods
# - demigods
# - heroes
# - villains
# - mortals
# Verbs - Change
# - create
# - shepherd
# - free
# - control
# - usurp
# Objects - Industries
# - cosmos
# - planets 🪐
# - life
# - emotion
# - social
#
#
# 1. Philosophy*
# 2. Knowledge
# 3. Error (Morality)
# 4. Variance/Bias
# 5. Informativeness/Control
#
# Agent/Force - Elon Musk (attributable)
# Verb/Acceleration** - Cars (eg electric: high icc)
# Object/Effects- People (measures or verbs)
#
# ** harder, better, faster, stronger (what jobs calls evolving from walking to bicycle)
#
# ---
#
#
# Effects/Services/Products
# - Buy
# - Own
# - Rent
# - Desire
#
# 1. Electric car, iPhone, LVMH, c(OS)
# 2. Correlation among buyers, owners?
# 3. Yes, under the spell or sway of Billionaire*
#
# *or whatever in nature is harder, faster, stronger
#
# ---
#
# - Generative AI
# - Augment skills of user
# - To become harder, better, faster, stronger
#
# Title on education???
#
# Variance (benefit, distinction for users)
# 1. AI makes its users harder, better, faster, stronger
# 2. The only ethical question in this domain then is equity/access to AI (not whether you should use it)
#
# Bias (harm, selective for unable to secure 🆔)
# 1. Equity-justice-privacy with biased algorithms
# 2. AI is only as good as the data it was trained on
# 3. Generative AI as well as XX AI may make harder, better, faster, stronger the very systemic biases underlying the data-generating process on which it’s algorithms were trained
#
# ---
#
# 1. Agents
# 2. Sway
#          - harder
#          - better
#          - faster
#          - stronger
#
# 3. Objects
#
# ---
#
# High ICC:
# 1. Hardest, best, fastest, strongest
# 2. Effect, service or product
# 3. Force to reckon with
#
# ---
#
# We’ve achieved unity:
#
# 1. Language of physics
# 2. Nuance of society
# 3. Hierarchical structures
#
# ---
#
# 1. Agents (Nominal values & rank)
# 2. Verbs (Categorical, grouping value)
# 3. Objects (Sampling units with attribute)
#
# ---
#
# That’s the ultimate “causal” framework
#
# ---
#
# (Verb)
# Categorical variable could have values such as 1-Electric car, 2-iPhone, 3-LVMH, 4-c(OS)
#
# (Object)
# A high intraclass correlation (eg phone brand owned by teenagers in the US from 2020-2023)
#
# (Agent)
# This could point to an agent like Jobs or Apple, who has sway; who holds sway; is the “force” to reckon with; dare I say, is the “cause”
#
# ---
#
# No wonder Steve Jobs dedicated a lot of resources to “information distortion”
#
# ---
#
# Isn’t this precisely what Kasenene does??
#
# ---
#
# Back-at-one:
#
# Process that produces data
#
# 1. True
# 2. Know
# 3. Right
#
# ---
#
# 1. Force - Agent
# 2. Momentum* - Verb
# 3. Object
#
# ---
#
# 1. F
# 2. ma
# 3. Object
#
# * harder, better, faster, stronger
#
# ---
#
# A “force to reckon with” has an effect on its object, man, which essentially is the desire to posses that service & product that augment their skills or person to make them harder, better, faster, stronger
#
# Often “hype”, information distortion, advertising, or propaganda in the political realm go far in influencing buying behaviors
#
# So let’s augment analysts at Hopkins. Let’s hype it until we have high ICC for:
#
# 1. Mode of presentation (Jupyter books)
# 2. Workflow (VSCode to GitHub)
# 3. Version control
# 4. Open science
# 5. Sharing code
# 6. Project & collaboration
#
# ---
#
# F = ma
#
# Fena (Agent)= Object*Acceleration (Verb)
#
# ---
#
# Objected: Accelerated personal growth
#
# ---
#
# F = m*a (agent); ubermench
# W = F*d (workflow: verb); do
# O = desirous of F’s superpowers; be like
#
# ---
#
# Such folks never right autobiographies. They biographies are written by others. But Walter Isaacson
#
# ---
#
# You are a force to be reckoned with
# Work* > humanly possible; übermench
# If superpowers are for sell; then what?
#
# *accomplish
#
# ---
#
# F=ma, Ubermench
# W=Fd > Man
# Repeat
#
# ---
#
# Everyone [x] uses SpaceX, Tesla, and starlink
#
# x - in need of space travel, zero emission car, etc
#
# High ICC
# </Details>
#
# </Details>
#
# <Details>
# <Summary>3. Error (Morality)</Summary>
#
#
# 1. Agents
# 2. Sway
#          - harder
#          - better
#          - faster
#          - stronger
#
# 3. Objects
# ---
#
# High ICC:
# 1. Hardest, best, fastest, strongest
# 2. Effect, service or product
# 3. Force to reckon with
#
# ---
#
# We’ve achieved unity:
#
# 1. Language of physics
# 2. Nuance of society
# 3. Hierarchical structures
#
# ---
#
# 1. Agents (Nominal values & rank)
# 2. Verbs (Categorical, grouping value)
# 3. Objects (Sampling units with attribute)
#
# ---
#
# That’s the ultimate “causal” framework
#
# </Details>
#
# <Details>
#   <Summary>4. Variance/Bias</Summary>
#
# (Verb)
# Categorical variable could have values such as 1-Electric car, 2-iPhone, 3-LVMH, 4-c(OS)
#
# (Object)
# A high intraclass correlation (eg phone brand owned by teenagers in the US from 2020-2023)
#
# (Agent)
# This could point to an agent like Jobs or Apple, who has sway; who holds sway; is the “force” to reckon with; dare I say, is the “cause”
#
# ---
#
# No wonder Steve Jobs dedicated a lot of resources to “information distortion”
#
# ---
#
# Isn’t this precisely what Kasenene does??
#
# ---
#
# Back-at-one:
#
# Process that produces data
#
# 1. True
# 2. Know
# 3. Right
#
# ---
#
# 1. Force - Agent
# 2. Momentum* - Verb
# 3. Object
#
# ---
#
# 1. F
# 2. ma
# 3. Object
#
# * harder, better, faster, stronger
#
#
# </Details>
#
# <Details>
# <Summary>5. Informativeness/Control</Summary>
#
# A “force to reckon with” has an effect on its object, man, which essentially is the desire to posses that service & product that augment their skills or person to make them harder, better, faster, stronger
#
# Often “hype”, information distortion, advertising, or propaganda in the political realm go far in influencing buying behaviors
#
# So let’s augment analysts at Hopkins. Let’s hype it until we have high ICC for:
#
# 1. Mode of presentation (Jupyter books)
# 2. Workflow (VSCode to GitHub)
# 3. Version control
# 4. Open science
# 5. Sharing code
# 6. Project & collaboration
#
# ------
#
# F = ma
#
# Fena (Agent)= Object*Acceleration (Verb)
#
# ---
#
# Objected: Accelerated personal growth
#
# ---
#
# F = m*a (agent); ubermench
# W = F*d (workflow: verb); do
# O = desirous of F’s superpowers; be like
#
# ---
#
# Such folks never right autobiographies. They biographies are written by others. But Walter Isaacson
#
# ---
#
# You are a force to be reckoned with
# Work > humanly possible; übermench
# If superpowers are for sell; then what?
#
# *accomplish
#
# ---
#
# F=ma, Ubermench
# W=Fd > Man
# Repeat
#
# ---
#
# Everyone [x] uses SpaceX, Tesla, and starlink
#
# x - in need of space travel, zero emission car, etc
#
# </Details>
#
# ---
#
# Your entry is an ambitious blend of physics, philosophy, and data science, exploring the conceptual frameworks that underlie various domains. Given its scope and complexity, it might be helpful to consider adding a few elements to make the entry more digestible for readers:
#
# 1. **Introduction**: Start with an abstract or an introductory paragraph summarizing the key points and themes that will be covered. This helps set the stage for what the reader can expect.
#
# 2. **Background**: Since you're diving into complex issues like philosophy, physics equations, and the concept of Intraclass Correlations (ICCs), a brief background or literature review would provide context.
#
# 3. **Thematic Breaks**: Consider using thematic breaks or subtitles for different sections, such as "Agents", "Verbs", "Objects", etc. This will help readers navigate through your ideas more effectively.
#
# 4. **Mathematical Notation**: When using equations or mathematical symbols, make sure to explain the variables and constants for the readers who may not have a background in physics or mathematics.
#
# 5. **Case Studies or Examples**: Concrete examples would go a long way in elucidating the abstract themes you are discussing. For instance, when talking about "Agents" like Elon Musk, you might explore Tesla's impact on the electric vehicle industry.
#
# 6. **Visual Aids**: Graphs, flowcharts, or even illustrations can break down complex issues and make them easier to understand. These would be particularly useful in a Jupyter Book format.
#
# 7. **Discussion and Analysis**: Delve into the implications of your frameworks. This could include the morality of influencing buying behaviors through 'hype', as you mentioned.
#
# 8. **Conclusion**: Tie all the concepts together, summing up what can be concluded and what further research or thought is necessary.
#
# 9. **References**: Given the breadth of subjects you’re tackling, citing relevant work can enhance the credibility of your narrative.
#
# 10. **Interactive Elements**: Since you're using Jupyter-books, you could include interactive Python code cells that allow the reader to engage with your ideas more dynamically.
#
# 11. **Next Steps**: Given your interest in ICCs and data generating processes, perhaps add a section on how these frameworks could guide future empirical research or real-world applications.
#
# For your workflow, you can structure the Jupyter-book in the following manner:
# - Use Jupyter notebooks for drafting each section.
# - Push these notebooks to a GitHub repository for version control.
# - When you're ready, convert these notebooks into the Jupyter Book format.
#
# Given the depth and breadth of the topics you're covering, you might find it helpful to collaborate with experts from different departments, leveraging their specialized knowledge to enrich your work.
#
# Your project is highly ambitious, and if executed well, it could offer valuable insights across multiple disciplines. Good luck!
