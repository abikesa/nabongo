# %% [markdown]
# #
#
# # 35
#
# common features in great works of art: [eastern promises](https://play.max.com/movie/ca436060-3cad-4a91-bbd8-bf68a20acf95)
#
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         .expanded-info {
#             display: none;
#         }
#     </style>
# </head>
# <body>
#     <p>
#         &emsp;1. <span class="expanded-word"></span> icc is metaphor for the patriachal-hierarchical society such as russian mafia
#     </p>
#     <p>
#         &emsp;2. <span class="expanded-word"></span> our protagonists tattooes catalog his journey (intercept & slope)
#     </p>
#     <p>
#         &emsp;3. this <span class="expanded-word" onclick="toggleExpand('gary')">shibboleth</span> will protect you or have your throat slit
#     </p>
#     <div id="gary" class="expanded-info">
#         <p>
#             &emsp;&emsp; This craving for community of worship is the chief misery of every man [individually](https://www.gutenberg.org/files/28054/28054-h/28054-h.htm) and of all [humanity](https://www.gutenberg.org/files/28054/28054-h/28054-h.htm) from the beginning of time
#         </p>
#     </div>
#     <script>
#         function toggleExpand(elementId) {
#             var expandedInfo = document.getElementById(elementId);
#             if (expandedInfo.style.display === 'none' || expandedInfo.style.display === '') {
#                 expandedInfo.style.display = 'block';
#             } else {
#                 expandedInfo.style.display = 'none';
#             }
#         }
#     </script>
# </body>
# </html>
#
# ---
#
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         .expanded-info {
#             display: none;
#         }
#     </style>
#     <script>
#         function toggleExpand() {
#             var expandedInfo = document.querySelector('.expanded-info');
#             if (expandedInfo.style.display === 'none' || expandedInfo.style.display === '') {
#                 expandedInfo.style.display = 'block';
#             } else {
#                 expandedInfo.style.display = 'none';
#             }
#         }
#     </script>
# </head>
# <body>
#     <p>
#         &emsp;1. <span class="expanded-word">Intercept</span> is the original group's average.
#     </p>
#     <p>
#         &emsp;2. <span class="expanded-word">Dramatic arc</span> is the slope leading us to the new group average.
#     </p>
#     <p>
#         &emsp;3. Think: <span class="expanded-word" onclick="toggleExpand('gary')">F. Gary Gray</span> from Compton to Hollywood.
#     </p>
#     <div id="gary" class="expanded-info">
#         <p>
#             &emsp;&emsp; F. Gary Gray is a highly acclaimed director known for his work in both film and music videos. He rose to &emsp;&emsp; prominence with groundbreaking music videos for artists like Ice Cube and Dr. Dre. Gray's talent and &emsp;&emsp; creativity eventually led him to the world of feature films, where he directed successful movies like &emsp;&emsp; &emsp;&emsp; "Straight Outta Compton" and "The Fate of the Furious." His journey from Compton to becoming a &emsp;&emsp; &emsp;&emsp; Hollywood elite showcases his remarkable career in the entertainment industry.
#         </p>
#     </div>
# </body>
# </html>
